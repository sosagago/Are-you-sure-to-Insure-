# %% [markdown]
# <a href="https://colab.research.google.com/github/utk1801/Are-you-sure-to-Insure-/blob/master/Greyatom_Hack_a_thon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.read_csv('train.csv')
# Out:
#           ID Agency    Agency Type  ... Commision (in value) Gender    Age
# 0       3433    CWT  Travel Agency  ...                17.82    NaN   31.0
# 1       4339    EPX  Travel Agency  ...                 0.00    NaN   36.0
# 2      34590    CWT  Travel Agency  ...                11.88    NaN   75.0
# 3      55816    EPX  Travel Agency  ...                 0.00    NaN   32.0
# 4      13816    EPX  Travel Agency  ...                 0.00    NaN   29.0
# 5      50349    CWT  Travel Agency  ...                29.70    NaN   36.0
# 6       9921    JZI       Airlines  ...                24.15      F   26.0
# 7      21923    JZI       Airlines  ...                 9.10      M   60.0
# 8       2236    CWT  Travel Agency  ...                11.88    NaN   57.0
# 9      14486    EPX  Travel Agency  ...                 0.00    NaN   47.0
# 10      5470    EPX  Travel Agency  ...                 0.00    NaN   36.0
# ...

# %%
data=pd.read_csv('train.csv')

# %%
data.describe()
# Out:
#                  ID         Claim  ...  Commision (in value)           Age
# count  50553.000000  50553.000000  ...           50553.00000  50553.000000
# mean   31679.740134      0.014658  ...               9.83809     40.011236
# std    18288.265350      0.120180  ...              19.91004     14.076566
# min        0.000000      0.000000  ...               0.00000      0.000000
# 25%    15891.000000      0.000000  ...               0.00000     35.000000
# 50%    31657.000000      0.000000  ...               0.00000     36.000000
# 75%    47547.000000      0.000000  ...              11.55000     44.000000
# max    63325.000000      1.000000  ...             283.50000    118.000000
#
# [8 rows x 6 columns]

# %%
data.size
# Out:
# 606636

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50553 entries, 0 to 50552
# Data columns (total 12 columns):
# ID                      50553 non-null int64
# Agency                  50553 non-null object
# Agency Type             50553 non-null object
# Distribution Channel    50553 non-null object
# Product Name            50553 non-null object
# Claim                   50553 non-null int64
# Duration                50553 non-null int64
# Destination             50553 non-null object
# Net Sales               50553 non-null float64
# Commision (in value)    50553 non-null float64
# Gender                  14600 non-null object
# Age                     50553 non-null int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 4.6+ MB

# %%
data.shape
# Out:
# (50553, 12)
